# %% [markdown]
# <a href="https://colab.research.google.com/github/SamyakTr/Customer-Segmentation-Using-Clustering/blob/main/CustomerSegmentation_Student.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kmodes
# Out:
# Collecting kmodes
#   Downloading kmodes-0.12.2-py2.py3-none-any.whl (20 kB)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.10/dist-packages (from kmodes) (1.25.2)
# Requirement already satisfied: scikit-learn>=0.22.0 in /usr/local/lib/python3.10/dist-packages (from kmodes) (1.2.2)
# Requirement already satisfied: scipy>=0.13.3 in /usr/local/lib/python3.10/dist-packages (from kmodes) (1.11.4)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.10/dist-packages (from kmodes) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.0->kmodes) (3.5.0)
# Installing collected packages: kmodes
# Successfully installed kmodes-0.12.2

# %% [markdown]
# # **Customer Segmentation using clustering**
#
# Customer segmentation is the process of dividing customers into specific groups or categories that best describe their common behaviors and interests.
#
# In this assignment, you will perform a customer segmentation for bank customer to identify the credit worthiness using various clustering methods.
#
# ## **Learning Objective**
#
# By the end of this assignment, a student will be able to:
#
# - Perform data analysis and identify the features suitable for clustering.
#
# - Apply different clustering methods for customer segmentation.
#
# - Analyze the results of clustering and pick the best approach.

# %% [markdown]
# ## **Data Descriptions**
#
#
#
# For this assignment, we are going to use the **German Credit(Statlog) Dataset**. This data set contains data used to evaluate credit applications in Germany. It has 1000 instances with 20 categorical attributes, but in this assignment, we will use the clean version of this dataset with just `8` attributes.
#
# **Source:** https://archive.ics.uci.edu/ml/datasets/Statlog+%28German+Credit+Data%29
#
# **Author:** Professor Dr. Hans Hofmann
#
# **Original Source:** Professor Dr. Hans Hofmann, Institut f"ur Statistik und "Okonometrie, Universit"at Hamburg, FB Wirtschaftswissenschaften, Von-Melle-Park 5, 2000 Hamburg 13
#
#
# **Number of Instances:** 1000
# **Number of Attributes:** 8
#
# **Attribute Information:**
# The detail information of each attribute:
#
# 1. Age (numeric)
# 2. Sex (text: male, female)
# 3. Job (numeric: 0 - unskilled and non-resident, 1 - unskilled and resident, 2 - skilled, 3 - highly skilled)
# 4. Housing (text: own, rent, or free)
# 5. Saving accounts (text - little, moderate, quite rich, rich)
# 6. Checking account (numeric, in DM - Deutsch Mark)
# 7. Credit amount (numeric, in DM)
# 8. Duration (numeric, in a month)
# 9. Purpose (text: car, furniture/equipment, radio/TV, domestic appliances, repairs, education, business, vacation/others)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings

# %%
warnings.filterwarnings("ignore")
sns.set_style('whitegrid')
sns.set_palette('rainbow')

plt.rcParams['figure.figsize'] = (10, 5)

# %%
import gdown

# !gdown https://drive.google.com/uc?id=1owZdscvaq3vv0hSdagxW-eiXXaRVetA2
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1owZdscvaq3vv0hSdagxW-eiXXaRVetA2
# To: /content/bank_credit_clean (1).csv
# 100% 44.6k/44.6k [00:00<00:00, 55.6MB/s]

# %%
df=pd.read_csv("/content/bank_credit_clean (1).csv")
df.head()
# Out:
#    Age     Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 0   67    male    2     own             NaN           little           1169
# 1   22  female    2     own          little         moderate           5951
# 2   49    male    1     own          little              NaN           2096
# 3   45    male    2    free          little           little           7882
# 4   53    male    2    free          little           little           4870
#
#    Duration              Purpose
# 0         6             radio/TV
# 1        48             radio/TV
# 2        12            education
# 3        42  furniture/equipment
# 4        24                  car

# %% [markdown]
# ## Data Informations
#
# In the following few sections, we will visualize our data and try to get some insight into the dataset. We will see if the given attributes/features in the dataset can help in customer segmentation or not and see which clustering methods help to best segment the customers.
#
# First off, let's look at the dataset information.

# %%
## Run this cell

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               1000 non-null   int64
#  1   Sex               1000 non-null   object
#  2   Job               1000 non-null   int64
#  3   Housing           1000 non-null   object
#  4   Saving accounts   817 non-null    object
#  5   Checking account  606 non-null    object
#  6   Credit amount     1000 non-null   int64
#  7   Duration          1000 non-null   int64
#  8   Purpose           1000 non-null   object
# dtypes: int64(4), object(5)
# memory usage: 70.4+ KB

# %% [markdown]
# Our dataset has `9` features with `4` numerical, `5` categorical features, and `1000` instances. `Job` is a number encoded categorical feature, so in total, we have only `3` numerical features. Our `Saving accounts` and `Checking account` have some missing values. We will do some data analysis and check for the feature importance; if these features are essential, we will perform necessary measures for missing value imputation.
#
# Now, since KMeans and other clustering algorithms works with numerical features, we will first segment our customers using our available numerical attributes like customer's Age, Credit amount and Duration. Later, we will use variant of KMeans for mixed features.

# %% [markdown]
# ## **Exercise 1: Data pre-processing**
#
# **[Points: 2]**
#
# In this exercise, you will perform some data pre-processing to fit it in a clustering model.
#
# **Task:**
#
#
# 1. Check for the data skewness and outliers then use appropriate transformation to fix the skewness and de-emphasizes outliers from the data (Decide the transformation method on your own).
# 2. Use `sklearn`'s standard scaler to scale the data.

# %%
## Select columns for clustering

selected_cols = ["Age","Credit amount", "Duration"] # using numerical features only
cluster_data = df.loc[:, selected_cols]

# %%
from mpl_toolkits.mplot3d import Axes3D

def _3d_data_plot(data, labels=None):
    """Wrapper for 3D data plot

    Parameters:
        data: pandas dataframe
        labels: labels of the data points(if available)

    """
    fig = plt.figure(figsize=(15,10))
    ax = fig.add_subplot(111, projection='3d')

    g = ax.scatter(data["Credit amount"], data["Duration"], data["Age"], c=labels if labels is not None else 'black', cmap='rainbow')
    ax.set_xlabel("Credit amount")
    ax.set_ylabel("Duration")
    ax.set_zlabel("Age")
    plt.tight_layout()


def scatter_plot(data, hue=None):
    """Wrapper for seaborn scatter plot.

    Parameters:
        data: pandas dataframe
        hue: variable to distinguish data w.r.t(optional)
        palette: color palette(optional)

    """
    fig, (ax1, ax2, ax3) = plt.subplots(3,1, figsize=(8,8))

    sns.scatterplot(x="Credit amount",y="Duration", hue=hue, data=data, ax=ax1, palette='rainbow')
    sns.scatterplot(x="Age",y="Credit amount", hue=hue, data=data, ax=ax2, palette='rainbow')
    sns.scatterplot(x="Age",y="Duration", hue=hue, data=data, ax=ax3, palette='rainbow')

    plt.tight_layout()

def box_plot(df):
    """Wrapper for box ploting

    Parameters:
        df: pandas dataframe
    """

    fig, ax = plt.subplots(1,3,figsize=(20,5))
    sns.boxplot(df['Credit amount'], ax=ax[0])
    sns.boxplot(df['Duration'], ax=ax[1])
    sns.boxplot(df['Age'], ax=ax[2])
    plt.tight_layout()

def distributions_plot(df):
    """Wrapper for ploting data distributions

    Parameters:
        df: pandas dataframe
    """
    fig, ax = plt.subplots(1, 3, figsize=(20,5))
    sns.distplot(df["Age"], ax=ax[0])
    sns.distplot(df["Credit amount"], ax=ax[1])
    sns.distplot(df["Duration"], ax=ax[2])
    plt.tight_layout()

# %%
## Plots
_3d_data_plot(cluster_data)
distributions_plot(cluster_data)
box_plot(cluster_data)

# %% [markdown]
# From the distribution plot we can see that given features are right skewed and from the box plots we can identify that data has outliers.

# %%
### Ex-1-Task-1
skew_fix_data = None

## Your code here ~ 1-4 lines

### BEGIN SOLUTION
# your code here
skew_fix_data = cluster_data.copy()
skew_fix_data['Age'] = np.log1p(skew_fix_data['Age'])
skew_fix_data['Credit amount'] = np.log1p(skew_fix_data['Credit amount'])
skew_fix_data['Duration'] = np.log1p(skew_fix_data['Duration'])
### END SOLUTION

distributions_plot(skew_fix_data)
box_plot(skew_fix_data)

# %%
assert skew_fix_data is not None, 'Invalid data'

# %% [markdown]
# Now that data we fixed the skewnees in data, let's scale our data using `sklearn`.

# %%
### Ex-1-Task-2
scaler = None
scaled_data = None

## Your code here ~ 3 lines

### BEGIN SOLUTION
# your code here
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_data = scaler.fit_transform(skew_fix_data)

### END SOLUTION

# %%
scaled_data.mean(), scaled_data.var()
# Out:
# (3.0849397110917683e-16, 1.0)

# %%
assert scaled_data is not None

# %% [markdown]
# ## **Exercise 2: _K_-Means Clustering**
#
# In this exercise, you will build a `KMeans` algorithm using `sklearn` and loop over a certain cluster range of cluster values to find the best `k` clusters.
#
# **[Points: 3]**
#
#
#
# **Task:**
#
#
# 1. From the certain cluster range, get the `inertia_` value from `KMeans` model for the elbow method.
# 2. Get the silhouette score from `KMeans` with different random sampling.
# 3. Analyze the `KMeans` results and pick the appropriate `n_clusters` value then build the final model.

# %%
### Ex-2-Task-1
clusters_range = None
inertias = []
kmeans = None

## Your code here ~ 3-5 lines

### BEGIN SOLUTION
# your code here
from sklearn.cluster import KMeans

clusters_range = range(2, 11)
for n_clusters in clusters_range:
    kmeans = KMeans(n_clusters=n_clusters, random_state=42)
    kmeans.fit(scaled_data)
    inertias.append(kmeans.inertia_)

### END SOLUTION

plt.plot(clusters_range, inertias, marker='o')
plt.show()

# %% [markdown]
# From the plot above, can you find the optimal number of clusters?
#
# If you can pick the optimal number of clusters, then use it to build a final model, but let's explore another alternative method for choosing optimal cluster value.
#
# Below you will generate ranges for `n_clusters` values and `random_state ` and try `KMeans` model on the different seed values with different `n_clusters`. This approach helps get the optimal cluster number where the silhouette values are stable with different `random_state` values.

# %%
### Ex-2-Task-2
from sklearn.metrics import silhouette_score

clusters_range = None # range of cluster values
random_range = None # range for random state
results = [] # results list with n_clusters, random_state and silhoette score

## Your code here ~ 4-8 lines

### BEGIN SOLUTION
# your code here
clusters_range = range(2, 11)
random_range = range(10)
for n_clusters in clusters_range:
    for random_state in random_range:
        kmeans = KMeans(n_clusters=n_clusters, random_state=random_state)
        kmeans.fit(scaled_data)
        silhouette_avg = silhouette_score(scaled_data, kmeans.labels_)
        results.append([n_clusters, random_state, silhouette_avg])
### END SOLUTION

## Create table
result = pd.DataFrame(results, columns=["n_clusters","random_state","silhouette_score"])
pivot_km = pd.pivot_table(result, index="n_clusters", columns="random_state", values="silhouette_score")

## Plot table
plt.figure(figsize=(15,6))
sns.heatmap(pivot_km, annot=True, linewidths=.5, fmt='.3f', cmap=sns.cm.rocket_r)
plt.tight_layout()

# %% [markdown]
# Now, by analyzing the table above, pick the optimal `random_state` and `n_clusters` value (Pick the one with stable values) and build your final `KMeans` model.

# %%
### Ex-2-Task-3
final_kmeans = None
labels = None

## Your code here ~ 2 lines

### BEGIN SOLUTION
# your code here
final_kmeans = KMeans(n_clusters=2, random_state=0)
final_kmeans.fit(scaled_data)

labels = final_kmeans.labels_
### END SOLUTION

clustered_data = cluster_data.assign(Cluster=labels)

# %%
## Plot clustered data
scatter_plot(clustered_data, 'Cluster')

# %% [markdown]
# ### KMeans Results

# %%
grouped_km = clustered_data.groupby(['Cluster']).mean().round(1)
grouped_km
# Out:
#           Age  Credit amount  Duration
# Cluster
# 0        35.7         1589.5      13.0
# 1        35.3         5229.7      30.1

# %% [markdown]
# The above dataframe shows the age of the customer with an average credit amount and the average duration.
#
# Let's visualize the clusters in 3D for our 3-dimensional features.

# %%
_3d_data_plot(clustered_data, labels=final_kmeans.labels_)

# %% [markdown]
# ## **Exercise 3: Hierarchical clustering**
#
# **[Points: 3]**
#
# Now that you have seen how `KMeans` clusters the data, let's look at the implementation of hierarchical clustering methods and analyze if it does better than `KMeans` or not.
#
# In this exercise, you will build a hierarchical clustering model and analyze the results.
#
# **Task:**
#
#
# 1. Build a linkage using `scipy` for our data with `method` of your own knowledge.
#
# 2. Build a dendrogram to identify the number of clusters.
#
# 3. Build `AgglomerativeClustering` model from scratch with the best `n_cluster` value.

# %%
### Ex-3-Task-1
plt.figure(figsize=(20, 10))

linkage_method = None

### BEGIN SOLUTION
# your code here
linkage_method = 'ward'
### END SOLUTION

# %%
### Ex-3-Task-2
hac_model = None
hac_labels = None

### BEGIN SOLUTION
# your code here
from sklearn.cluster import AgglomerativeClustering

hac_model = AgglomerativeClustering(n_clusters=2, linkage=linkage_method)
hac_labels = hac_model.fit_predict(scaled_data)

### END SOLUTION

# %%
assert hac_model is not None
assert hac_labels is not None

# %%
df_clustered_hac = cluster_data.assign(Cluster=hac_labels)
grouped_hac = df_clustered_hac.groupby(['Cluster']).mean().round(1)
print(grouped_hac)
_3d_data_plot(cluster_data, labels=hac_labels)
# Out:
#           Age  Credit amount  Duration
# Cluster
# 0        33.1         2051.6      16.2
# 1        41.2         6077.0      31.7

# %%
scatter_plot(df_clustered_hac, 'Cluster')

# %% [markdown]
# ## **Exercise 4: _K_-Prototypes for mixed features**
#
# In this exercise, you will build a variant of `KMeans` algorithm to cluster the mixed features.
#
# **[Points: 2]**
#
#
#
# **Task:**
#
#
# 1. Fill the missing values identified earlier with appropriate imputation method.
# 2. Use `_K_-Prototypes` algorithm to prepare clusters from all the available features (numerical + categorical)
# 3. Pass column index of categorical features as a list to an algorithm to identify the categorical features
#
# **Note:** `KPrototypes` has a same pipelie as `sklearn`'s other algorithms

# %%
### Ex-4-Task-1
from kmodes.kprototypes import KPrototypes

kp_labels = None
categorical_indexes = []

### BEGIN SOLUTION
# your code here


categorical_features = df.select_dtypes(include=['object']).columns.tolist()
categorical_indexes = [df.columns.get_loc(col) for col in categorical_features]
from sklearn.impute import SimpleImputer

# Impute missing values for categorical features with most frequent value
cat_imputer = SimpleImputer(strategy='most_frequent')
df[categorical_features] = cat_imputer.fit_transform(df[categorical_features])
k_prototypes = KPrototypes(n_clusters=3, init='Huang', n_init=5, verbose=1)
kp_labels = k_prototypes.fit_predict(df, categorical=categorical_indexes)

### END SOLUTION
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 1, iteration: 1/100, moves: 446, ncost: 2535412102.0957456
# Run: 1, iteration: 2/100, moves: 325, ncost: 1692820878.6090717
# Run: 1, iteration: 3/100, moves: 149, ncost: 1502733718.5554543
# Run: 1, iteration: 4/100, moves: 80, ncost: 1430792702.518557
# Run: 1, iteration: 5/100, moves: 60, ncost: 1366833279.381406
# Run: 1, iteration: 6/100, moves: 39, ncost: 1347998172.8701687
# Run: 1, iteration: 7/100, moves: 20, ncost: 1339219999.800218
# Run: 1, iteration: 8/100, moves: 20, ncost: 1331162758.8858702
# Run: 1, iteration: 9/100, moves: 17, ncost: 1317220647.6025555
# Run: 1, iteration: 10/100, moves: 11, ncost: 1311126874.5555906
# Run: 1, iteration: 11/100, moves: 9, ncost: 1305589461.974306
# Run: 1, iteration: 12/100, moves: 18, ncost: 1297155767.3027344
# Run: 1, iteration: 13/100, moves: 16, ncost: 1292444069.598698
# Run: 1, iteration: 14/100, moves: 8, ncost: 1291715179.9891734
# Run: 1, iteration: 15/100, moves: 8, ncost: 1290409099.591274
# Run: 1, iteration: 16/100, moves: 17, ncost: 1282072419.7200677
# Run: 1, iteration: 17/100, moves: 6, ncost: 1280578772.5134041
# Run: 1, iteration: 18/100, moves: 2, ncost: 1280160743.526899
# Run: 1, iteration: 19/100, moves: 6, ncost: 1278895612.602869
# Run: 1, iteration: 20/100, moves: 2, ncost: 1278846367.3378134
# Run: 1, iteration: 21/100, moves: 0, ncost: 1278846367.3378134
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 2, iteration: 1/100, moves: 63, ncost: 1479879408.428172
# Run: 2, iteration: 2/100, moves: 62, ncost: 1398027508.0341358
# Run: 2, iteration: 3/100, moves: 56, ncost: 1356503733.9073656
# Run: 2, iteration: 4/100, moves: 26, ncost: 1343678671.4386566
# Run: 2, iteration: 5/100, moves: 28, ncost: 1332303969.9575763
# Run: 2, iteration: 6/100, moves: 19, ncost: 1317478710.401857
# Run: 2, iteration: 7/100, moves: 12, ncost: 1311126874.5555906
# Run: 2, iteration: 8/100, moves: 9, ncost: 1305589461.974306
# Run: 2, iteration: 9/100, moves: 18, ncost: 1297155767.3027344
# Run: 2, iteration: 10/100, moves: 16, ncost: 1292444069.598698
# Run: 2, iteration: 11/100, moves: 8, ncost: 1291715179.9891734
# Run: 2, iteration: 12/100, moves: 8, ncost: 1290409099.591274
# Run: 2, iteration: 13/100, moves: 17, ncost: 1282072419.7200677
# Run: 2, iteration: 14/100, moves: 6, ncost: 1280578772.5134041
# Run: 2, iteration: 15/100, moves: 2, ncost: 1280160743.526899
# Run: 2, iteration: 16/100, moves: 6, ncost: 1278895612.602869
# Run: 2, iteration: 17/100, moves: 2, ncost: 1278846367.3378134
# Run: 2, iteration: 18/100, moves: 0, ncost: 1278846367.3378134
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 3, iteration: 1/100, moves: 46, ncost: 1333500633.4846947
# Run: 3, iteration: 2/100, moves: 12, ncost: 1323607883.5388906
# Run: 3, iteration: 3/100, moves: 15, ncost: 1313572810.8038418
# Run: 3, iteration: 4/100, moves: 5, ncost: 1310345727.4969814
# Run: 3, iteration: 5/100, moves: 10, ncost: 1304921119.8420968
# Run: 3, iteration: 6/100, moves: 15, ncost: 1297155767.3027344
# Run: 3, iteration: 7/100, moves: 16, ncost: 1292444069.598698
# Run: 3, iteration: 8/100, moves: 8, ncost: 1291715179.9891734
# Run: 3, iteration: 9/100, moves: 8, ncost: 1290409099.591274
# Run: 3, iteration: 10/100, moves: 17, ncost: 1282072419.7200677
# Run: 3, iteration: 11/100, moves: 6, ncost: 1280578772.5134041
# Run: 3, iteration: 12/100, moves: 2, ncost: 1280160743.526899
# Run: 3, iteration: 13/100, moves: 6, ncost: 1278895612.602869
# Run: 3, iteration: 14/100, moves: 2, ncost: 1278846367.3378134
# Run: 3, iteration: 15/100, moves: 0, ncost: 1278846367.3378134
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 4, iteration: 1/100, moves: 149, ncost: 1540565538.6976147
# Run: 4, iteration: 2/100, moves: 56, ncost: 1465137736.5234406
# Run: 4, iteration: 3/100, moves: 60, ncost: 1388999753.3282628
# Run: 4, iteration: 4/100, moves: 47, ncost: 1354925735.2773483
# Run: 4, iteration: 5/100, moves: 31, ncost: 1340501119.3830993
# Run: 4, iteration: 6/100, moves: 24, ncost: 1331162758.8858702
# Run: 4, iteration: 7/100, moves: 17, ncost: 1317220647.6025555
# Run: 4, iteration: 8/100, moves: 11, ncost: 1311126874.5555906
# Run: 4, iteration: 9/100, moves: 9, ncost: 1305589461.974306
# Run: 4, iteration: 10/100, moves: 18, ncost: 1297155767.3027344
# Run: 4, iteration: 11/100, moves: 16, ncost: 1292444069.598698
# Run: 4, iteration: 12/100, moves: 8, ncost: 1291715179.9891734
# Run: 4, iteration: 13/100, moves: 8, ncost: 1290409099.591274
# Run: 4, iteration: 14/100, moves: 17, ncost: 1282072419.7200677
# Run: 4, iteration: 15/100, moves: 6, ncost: 1280578772.5134041
# Run: 4, iteration: 16/100, moves: 2, ncost: 1280160743.526899
# Run: 4, iteration: 17/100, moves: 6, ncost: 1278895612.602869
# Run: 4, iteration: 18/100, moves: 2, ncost: 1278846367.3378134
# Run: 4, iteration: 19/100, moves: 0, ncost: 1278846367.3378134
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 5, iteration: 1/100, moves: 158, ncost: 1561329220.2922282
# Run: 5, iteration: 2/100, moves: 90, ncost: 1477111019.3141754
# Run: 5, iteration: 3/100, moves: 71, ncost: 1399747590.3053274
# Run: 5, iteration: 4/100, moves: 55, ncost: 1357162360.3594513
# Run: 5, iteration: 5/100, moves: 26, ncost: 1345581763.468641
# Run: 5, iteration: 6/100, moves: 18, ncost: 1337047313.1182399
# Run: 5, iteration: 7/100, moves: 19, ncost: 1328330716.2112439
# Run: 5, iteration: 8/100, moves: 15, ncost: 1316730417.5212972
# Run: 5, iteration: 9/100, moves: 9, ncost: 1311126874.5555906
# Run: 5, iteration: 10/100, moves: 9, ncost: 1305589461.974306
# Run: 5, iteration: 11/100, moves: 18, ncost: 1297155767.3027344
# Run: 5, iteration: 12/100, moves: 16, ncost: 1292444069.598698
# Run: 5, iteration: 13/100, moves: 8, ncost: 1291715179.9891734
# Run: 5, iteration: 14/100, moves: 8, ncost: 1290409099.591274
# Run: 5, iteration: 15/100, moves: 17, ncost: 1282072419.7200677
# Run: 5, iteration: 16/100, moves: 6, ncost: 1280578772.5134041
# Run: 5, iteration: 17/100, moves: 2, ncost: 1280160743.526899
# Run: 5, iteration: 18/100, moves: 6, ncost: 1278895612.602869
# Run: 5, iteration: 19/100, moves: 2, ncost: 1278846367.3378134
# Run: 5, iteration: 20/100, moves: 0, ncost: 1278846367.3378134
# Best run was number 1

# %%
kp_assigned = df.assign(Cluster=kp_labels)
_3d_data_plot(df, kp_labels)

# %%
scatter_plot(kp_assigned, 'Cluster')

# %%
fig = plt.figure(figsize = (20,15))
axes = 320
for cat in df.columns[categorical_indexes]:
    axes += 1
    fig.add_subplot(axes)
    sns.countplot(data = kp_assigned, hue=kp_assigned['Cluster'], x = cat)
    plt.xticks(rotation=30)
plt.show()

# %% [markdown]
# <center>
#     <b>THE END</b>
# </center>
